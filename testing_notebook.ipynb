# %% [markdown]
# # Notebook used to rest random and small things

# %%
tuple_list = [(1, 2), (3, 4)]

print(tuple_list[0][0])
# Out:
# 1

# %%
145/10
# Out:
# 14.5

# %%
from datetime import datetime, timedelta
from zoneinfo import ZoneInfo

ny_tz = ZoneInfo('America/New_York')
current_datetime = datetime.now(ny_tz)
current_date = current_datetime.strftime('%B_%d_%Y')
current_time = current_datetime.strftime('%H:%M:%S')

print(current_datetime)
print(current_date)
print(current_time)
# Out:
# 2025-04-30 18:47:30.060030-04:00
# April_30_2025
# 18:47:30

# %%
# calculating stop time
start_time = datetime.now(ny_tz)
stop_time = start_time + timedelta(seconds=3)

while datetime.now(ny_tz) < stop_time:
    print(f'{datetime.now(ny_tz).strftime(('%H:%M:%S'))}', flush=True)
# Out:
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# 18:50:23
# ...

# %%
tup = (1, 3)
print(tup[0], tup[1])
# Out:
# 1 3

# %%
import json

# Path to JSON config (assuming default dir)
config_path = os.path.join(os.path.dirname(__file__), 'sensor_config.json')

def load_config():
    with open(config_path) as config_file:
        return json.load(config_file)
    
def save_config(cfg):
    with open(config_path, 'w') as config_file:
        json.dump(cfg, f, indent=2)

def prompt_config_values(cfg, key, cast_fn):
    default = cfg[key]
    user_reply = None
    while input(f'{key} (current: {default}). Would you like to change this? (y/n)').strip().lower() not in ['y', 'yes']:
        # user_reply = input(f'{key} (current: {default}). Would you like to change this? (y/n)').strip().lower()
        if user_reply == 'y' or user_reply == 'yes':
            user_input = input(f'Enter new value for {key}: ').strip()
            cfg[key] = cast_fn(user_input)
        elif user_reply == 'n' or user_reply == 'no':
            print('Keeping {default} value for {key}.') 
            break
        else:
            print('Please enter y or n.')
# Out:
#   Cell In[12], line 17
#     while user_reply = input(f'{key} (current: {default}). Would you like to change this? (y/n)').strip().lower() not in ['y', 'yes']:
#           ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
while user_reply = input(f'{key} (current: {default}). Would you like to change this? (y/n)').strip().lower() not in ['y', 'yes']:
        # user_reply = input(f'{key} (current: {default}). Would you like to change this? (y/n)').strip().lower()
        if user_reply == 'y' or user_reply == 'yes':
            user_input = input(f'Enter new value for {key}: ').strip()
            cfg[key] = cast_fn(user_input)
        elif user_reply == 'n' or user_reply == 'no':
            print('Keeping {default} value for {key}.') 
            break
        else:
            print('Please enter y or n.')
# Out:
#   Cell In[11], line 1
#     while user_reply = input(f'{key} (current: {default}). Would you like to change this? (y/n)').strip().lower() not in ['y', 'yes']:
#           ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
